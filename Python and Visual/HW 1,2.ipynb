# %%
rostelecom = ['ростелеком']

# %%
import re
pattern = '.*'
prog = re.compile( pattern )

# %%
rt = []
for lolo in range(len(rostelecom[0])):
    rt += rostelecom[0][lolo]
rt
# Out:
# ['р', 'о', 'с', 'т', 'е', 'л', 'е', 'к', 'о', 'м']

# %%
Ds = open('slovarr.txt', 'r')

# %%
slovar = []
for line in Ds:
    line = line.strip()
    if prog.match( line ):
        slovar += [line]
slovar
# Out:
# ['а.л.',
#  'а-конто',
#  'абажур',
#  'абажурный',
#  'абаз',
#  'абазинец',
#  'абазинка',
#  'абак',
#  'абака',
#  'абакан',
#  'абаканский',
#  'абакум',
#  'абандон',
#  'аббат',
#  'аббатский',
#  'аббатство',
#  'аббревиатура',
#  'аббревиатурный',
#  'абвер',
#  'абдель',
#  'абдикация',
#  'абдомен',
#  'абдоминальный',
#  'абдуктор',
#  'абдукция',
#  'абдуллаев',
#  'абеляр',
#  'аберрационный',
#  'аберрация',
#  'абзац',
#  'абзацный',
#  'абзетцер',
#  'абиджан',
#  'абиогенез',
#  'абиогенный',
#  'абиссальный',
#  'абиссиния',
#  'абиссинка',
#  'абитуриент',
#  'абитуриентка',
#  'аблатив',
#  'абляция',
#  'аболиционизм',
#  'аболиционист',
#  'аболиция',
#  'абонемент',
#  'абонементный',
#  'абонент',
#  'абонентка',
#  'абонентный',
#  'абонентский',
#  'абонировавший',
#  'абонировавшийся',
#  'абонирование',
#  'абонированный',
#  'абонировать',
#  'абонирующий',
#  'абонирующийся',
#  'абордаж',
#  'абордажный',
#  'абордировавший',
#  'абордировавшийся',
# ...

# %%
def next_word(slovar):
    new = []
    for i in range(len(slovar[new_word])):
        new += [slovar[new_word][i]]
    return new

# %%
def poisk_simb(new):
    dodo = 0
    for r in range(len(new)):
        rt.index(new[r])
        dodo += 1
    if dodo == len(new):
        return ''.join(new)

# %%
kolvo_slov = []
for new_word in range(len(slovar)):
    lineNumber = 1
    try:
        kolvo_slov += [poisk_simb(next_word(slovar))]
        #print(poisk_simb(next_word(slovar)))
    except:
        next
kolvo_slov
# Out:
# ['ее',
#  'емко',
#  'к',
#  'кекс',
#  'кермет',
#  'клекот',
#  'клерк',
#  'клок',
#  'км',
#  'ко',
#  'кок',
#  'кокк',
#  'кокос',
#  'кокс',
#  'кол',
#  'колесо',
#  'колко',
#  'коллектор',
#  'коло',
#  'колок',
#  'колокол',
#  'колос',
#  'колосок',
#  'колосс',
#  'ком',
#  'комок',
#  'комсомол',
#  'корм',
#  'коротко',
#  'корректор',
#  'корсет',
#  'корт',
#  'космос',
#  'косо',
#  'костел',
#  'костер',
#  'кот',
#  'котел',
#  'котелок',
#  'которое',
#  'крекер',
#  'крем',
#  'креол',
#  'кресло',
#  'крест',
#  'крокет',
#  'кроме',
#  'кросс',
#  'крот',
#  'кротко',
#  'ксерокс',
#  'кто',
#  'л',
#  'лек',
#  'лектор',
#  'лес',
#  'лесок',
#  'месото',
#  'лесс',
#  'лет',
#  'лето',
#  'леток',
#  'летом',
#  'лом',
#  'ломко',
#  'лоск',
#  'лот',
#  'лото',
#  'лоток',
#  'лотос',
#  'м',
#  'мел',
#  'мелко',
#  'мелок',
#  'мелор',
#  'мелос',
#  'местком',
#  'место',
#  'метеор',
#  'метко',
#  'метол',
#  'метр',
#  'метро',
#  'мм',
#  'мокко',
# ...

# %%
len(kolvo_slov)
# Out:
# 264
