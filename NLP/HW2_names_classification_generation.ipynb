# %% [markdown]
# #  Домашнее задание по NLP # 3 [100 баллов]
# ## Классификация и генерация фамилий
#
# В этом домашнем задании вам предстоит классифицировать и генерировать фамилии на 19 разных языках. Обучающие данные хранятся в папке data и разбиты по языкам: один язык – одна подпапка. Ниже представлен код для считывания данных в словарь вида:
# ```d{язык} : [список имен]```.

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import glob

def findFiles(path): return glob.glob(path)

print(findFiles('data/names/*.txt'))


def readLines(filename):
    lines = open(filename, encoding='utf-8').read().strip().split('\n')
    return lines

all_categories = []
category_lines = {}
for filename in findFiles('data/names/*.txt'):
    category = filename.split('/')[-1].split('.')[0]
    all_categories.append(category)
    lines = readLines(filename)
    category_lines[category] = lines

n_categories = len(all_categories)

print(category_lines['Russian'][100:120])
# Out:
# ['data/names/Czech.txt', 'data/names/German.txt', 'data/names/Arabic.txt', 'data/names/Japanese.txt', 'data/names/Chinese.txt', 'data/names/Vietnamese.txt', 'data/names/Russian.txt', 'data/names/French.txt', 'data/names/Irish.txt', 'data/names/English.txt', 'data/names/Spanish.txt', 'data/names/Greek.txt', 'data/names/Italian.txt', 'data/names/Portuguese.txt', 'data/names/Scottish.txt', 'data/names/Dutch.txt', 'data/names/Korean.txt', 'data/names/Polish.txt']
# ['Abels', 'Abelsky', 'Abeltsev', 'Abelyan', 'Aberson', 'Abertasov', 'Abesadze', 'Abezgauz', 'Abgaryan', 'Abibulaev', 'Abidoff', 'Abidov', 'Abih', 'Abikh', 'Abisaloff', 'Abisalov', 'Abitoff', 'Abitov', 'Abjaliloff', 'Abjalilov']

# %%
import pandas as pd 
p = pd.DataFrame([category_lines])

# %%
df = pd.DataFrame.from_dict(category_lines,orient='index').reset_index()

# %%
df=df.transpose().drop_duplicates()

# %%
df
# Out:
#                  0             1         2          3        4           5   \
# index         Czech        German    Arabic   Japanese  Chinese  Vietnamese
# 0               Abl        Abbing    Khoury        Abe      Ang      Nguyen
# 1             Adsit          Abel     Nahas    Abukara  Au-Yong        Tron
# 2            Ajdrna         Abeln     Daher     Adachi      Bai          Le
# 3               Alt           Abt    Gerges       Aida      Ban        Pham
# 4      Antonowitsch      Achilles    Nazari     Aihara      Bao       Huynh
# 5        Antonowitz    Achterberg   Maalouf     Aizawa      Bei       Hoang
# 6             Bacon         Acker    Gerges    Ajibana     Bian        Phan
# 7        Ballalatak     Ackermann    Naifeh     Akaike      Bui          Vu
# 8        Ballaltick          Adam  Guirguis   Akamatsu      Cai          Vo
# 9         Bartonova      Adenauer      Baba   Akatsuka      Cao        Dang
# 10            Bastl         Adler   Sabbagh     Akechi      Cen         Bui
# 11           Baroch  Adlersflügel     Attia      Akera     Chai          Do
# 12          Benesch    Aeschelman     Tahan    Akimoto    Chaim          Ho
# 13          Betlach        Albert    Haddad      Akita     Chan         Ngo
# 14         Biganska      Albrecht     Aswad    Akiyama    Chang       Duong
# 15            Bilek      Aleshire    Najjar  Akutagawa     Chao          Ly
# 16           Blahut      Aleshite    Dagher    Amagawa      Che          An
# 17           Blazek       Althaus    Maloof      Amaya     Chen          an
# 18           Blazek         Amsel       Isa      Amori    Cheng        Bach
# 19      Blazejovsky        Andres    Asghar      Anami   Cheung        Banh
# 20           Blecha    Armbrüster     Nader       Ando     Chew         Cao
# 21          Bleskan    Armbruster     Gaber      Anzai    Chieu        Chau
# 22           Blober          Artz    Abboud       Aoki     Chin         Chu
# 23             Bock           Aue   Maalouf       Arai    Chong       Chung
# 24            Bohac          Auer     Zogby    Arakawa     Chou         Chu
# 25       Bohunovsky      Augustin     Srour      Araki      Chu        Diep
# 26           Bolcar          Aust     Bahar    Arakida      Cui        Doan
# 27          Borovka     Autenburg   Mustafa      Arato      Dai         Dam
# 28         Borovski    Auttenberg   Hanania  Arihyoshi     Deng         Dao
# ...             ...           ...       ...        ...      ...         ...
# 9378           None          None      None       None     None        None
# 9379           None          None      None       None     None        None
# 9380           None          None      None       None     None        None
# 9381           None          None      None       None     None        None
# 9382           None          None      None       None     None        None
# 9383           None          None      None       None     None        None
# 9384           None          None      None       None     None        None
# 9385           None          None      None       None     None        None
# 9386           None          None      None       None     None        None
# 9387           None          None      None       None     None        None
# 9388           None          None      None       None     None        None
# 9389           None          None      None       None     None        None
# 9390           None          None      None       None     None        None
# 9391           None          None      None       None     None        None
# 9392           None          None      None       None     None        None
# 9393           None          None      None       None     None        None
# 9394           None          None      None       None     None        None
# 9395           None          None      None       None     None        None
# 9396           None          None      None       None     None        None
# 9397           None          None      None       None     None        None
# 9398           None          None      None       None     None        None
# 9399           None          None      None       None     None        None
# 9400           None          None      None       None     None        None
# 9401           None          None      None       None     None        None
# 9402           None          None      None       None     None        None
# 9403           None          None      None       None     None        None
# 9404           None          None      None       None     None        None
# 9405           None          None      None       None     None        None
# 9406           None          None      None       None     None        None
# 9407           None          None      None       None     None        None
#
#                  6            7           8         9            10  \
# index       Russian       French       Irish   English      Spanish
# 0            Ababko         Abel        Adam     Abbas        Abana
# 1             Abaev      Abraham      Ahearn     Abbey        Abano
# 2           Abagyan         Adam        Aodh    Abbott       Abarca
# 3         Abaidulin       Albert       Aodha      Abdi       Abaroa
# 4        Abaidullin       Allard    Aonghuis      Abel      Abascal
# 5          Abaimoff  Archambault     Aonghus   Abraham      Abasolo
# 6           Abaimov    Armistead    Bhrighde  Abrahams         Abel
# 7         Abakeliya       Arthur     Bradach    Abrams       Abelló
# 8         Abakovsky     Augustin      Bradan    Ackary    Aberquero
# 9          Abakshin    Babineaux      Braden   Ackroyd        Abreu
# 10        Abakumoff       Baudin       Brady     Acton       Acosta
# 11         Abakumov    Beauchene        Bran     Adair     Agramunt
# 12       Abakumtsev     Beaulieu     Brannon      Adam         Aiza
# 13        Abakushin     Beaumont       Brian     Adams     Alamilla
# 14         Abalakin     Bélanger   Callaghan   Adamson       Albert
# 15        Abalakoff      Bellamy       Caomh    Adanet  Albuquerque
# 16         Abalakov    Bellerose       Carey    Addams       Aldana
# 17        Abaleshev      Belrose       Casey  Adderley       Alfaro
# 18         Abalihin       Berger     Cassidy  Addinall     Alvarado
# 19        Abalikhin     Béringer     Cathain     Addis      Álvarez
# 20          Abalkin      Bernard      Cathan   Addison        Alves
# 21       Abalmasoff     Bertrand   Cathasach    Addley       Amador
# 22        Abalmasov       Bisset    Ceallach   Aderson       Andreu
# 23          Abaloff     Bissette  Ceallachan      Adey      Antúnez
# 24           Abalov       Blaise   Cearbhall    Adkins         Aqua
# 25         Abamelek        Blanc    Cennetig     Adlam       Aquino
# 26           Abanin     Blanchet     Ciardha     Adler       Araújo
# 27          Abankin    Blanchett       Clark     Adrol      Araullo
# 28        Abarinoff      Bonfils    Cleirich    Adsett        Araya
# ...             ...          ...         ...       ...          ...
# 9378       Zinyuhin         None        None      None         None
# 9379            Zis         None        None      None         None
# 9380          Zitev         None        None      None         None
# 9381      Zitserman         None        None      None         None
# 9382        Ziyakov         None        None      None         None
# 9383     Ziyatdinov         None        None      None         None
# 9384        Ziyazov         None        None      None         None
# 9385        Zobanov         None        None      None         None
# 9386         Zobkob         None        None      None         None
# 9387         Zobnin         None        None      None         None
# 9388          Zobov         None        None      None         None
# 9389        Zogalev         None        None      None         None
# 9390          Zolin         None        None      None         None
# 9391         Zolkin         None        None      None         None
# 9392         Zoloev         None        None      None         None
# 9393        Zolotai         None        None      None         None
# 9394        Zolotar         None        None      None         None
# 9395      Zolotarev         None        None      None         None
# 9396   Zolotarevsky         None        None      None         None
# 9397     Zolotarsky         None        None      None         None
# 9398      Zolotavin         None        None      None         None
# 9399     Zolotdinov         None        None      None         None
# 9400     Zolotenkov         None        None      None         None
# 9401      Zolotilin         None        None      None         None
# 9402       Zolotkov         None        None      None         None
# 9403    Zolotnitsky         None        None      None         None
# 9404    Zolotnitzky         None        None      None         None
# 9405         Zozrov         None        None      None         None
# 9406        Zozulya         None        None      None         None
# 9407       Zukerman         None        None      None         None
#
#                     11             12           13         14          15  \
# index            Greek        Italian   Portuguese   Scottish       Dutch
# 0             Adamidis     Abandonato        Abreu      Smith    Aalsburg
# 1               Adamou     Abatangelo  Albuquerque      Brown       Aalst
# 2             Agelakos    Abatantuono      Almeida     Wilson       Aarle
# 3         Akrivopoulos          Abate        Alves   Campbell    Achteren
# 4      Alexandropoulos  Abategiovanni       Araújo    Stewart   Achthoven
# 5             Anetakis   Abatescianni      Araullo    Thomson    Adrichem
# 6         Angelopoulos           Abbà       Barros  Robertson     Aggelen
# 7         Antimisiaris      Abbadelli      Basurto   Anderson     Agteren
# 8              Antipas       Abbascia         Belo  Macdonald    Agthoven
# 9            Antonakos    Abbatangelo       Cabral      Scott     Akkeren
# 10          Antoniadis   Abbatantuono       Campos       Reid       Aller
# 11        Antonopoulos         Abbate      Cardozo     Murray      Alphen
# 12        Antonopoulos      Abbatelli       Castro     Taylor        Alst
# 13        Antonopoulos    Abbaticchio       Coelho      Clark      Altena
# 14      Arvanitoyannis        Abbiati        Costa       Ross     Althuis
# 15           Avgerinos  Abbracciabene       Crespo     Watson  Amelsvoort
# 16               Banos  Abbracciabeni         Cruz   Morrison  Amersvoort
# 17            Batsakis         Abelli       D'cruz   Paterson      Amstel
# 18             Bekyros         Abelló      D'cruze      Young       Andel
# 19             Belesis         Abrami      Delgado   Mitchell    Andringa
# 20           Bertsimas         Abramo   De santigo     Walker     Ankeren
# 21              Bilias         Acardi       Duarte     Fraser     Antwerp
# 22              Blades        Accardi      Estéves     Miller   Antwerpen
# 23           Bouloukos        Accardo    Fernandes   Mcdonald   Apeldoorn
# 24       Brisimitzakis         Acciai     Ferreira       Gray    Arendonk
# 25            Bursinos        Acciaio     Ferreiro  Henderson        Asch
# 26         Calogerakis      Acciaioli        Ferro   Hamilton       Assen
# 27              Calpis        Acconci      Fonseca   Johnston      Baarle
# 28             Chellos       Acconcio       Franco     Duncan    Bokhoven
# ...                ...            ...          ...        ...         ...
# 9378              None           None         None       None        None
# 9379              None           None         None       None        None
# 9380              None           None         None       None        None
# 9381              None           None         None       None        None
# 9382              None           None         None       None        None
# 9383              None           None         None       None        None
# 9384              None           None         None       None        None
# 9385              None           None         None       None        None
# 9386              None           None         None       None        None
# 9387              None           None         None       None        None
# 9388              None           None         None       None        None
# 9389              None           None         None       None        None
# 9390              None           None         None       None        None
# 9391              None           None         None       None        None
# 9392              None           None         None       None        None
# 9393              None           None         None       None        None
# 9394              None           None         None       None        None
# 9395              None           None         None       None        None
# 9396              None           None         None       None        None
# 9397              None           None         None       None        None
# 9398              None           None         None       None        None
# 9399              None           None         None       None        None
# 9400              None           None         None       None        None
# 9401              None           None         None       None        None
# 9402              None           None         None       None        None
# 9403              None           None         None       None        None
# 9404              None           None         None       None        None
# 9405              None           None         None       None        None
# 9406              None           None         None       None        None
# 9407              None           None         None       None        None
#
#            16          17
# index  Korean      Polish
# 0         Ahn    Adamczak
# 1        Baik    Adamczyk
# 2        Bang   Andrysiak
# 3        Byon  Auttenberg
# 4         Cha     Bartosz
# 5       Chang     Bernard
# 6         Chi   Bobienski
# 7        Chin       Bosko
# 8         Cho        Broż
# 9        Choe   Brzezicki
# 10       Choi       Budny
# 11      Chong     Bukoski
# 12       Chou    Bukowski
# 13        Chu     Chlebek
# 14       Chun      Chmiel
# 15      Chung      Czajka
# 16      Chweh  Czajkowski
# 17        Gil  Dubanowski
# 18         Gu     Dubicki
# 19     Gwang     Dunajski
# 20         Ha    Dziedzic
# 21        Han      Fabian
# 22         Ho     Filipek
# 23       Hong  Filipowski
# 24       Hung       Gajos
# 25      Hwang     Gniewek
# 26      Hyun      Gomolka
# 27       Jang     Gomulka
# 28       Jeon     Gorecki
# ...       ...         ...
# 9378     None        None
# 9379     None        None
# 9380     None        None
# 9381     None        None
# 9382     None        None
# 9383     None        None
# 9384     None        None
# 9385     None        None
# 9386     None        None
# 9387     None        None
# 9388     None        None
# 9389     None        None
# 9390     None        None
# 9391     None        None
# 9392     None        None
# 9393     None        None
# 9394     None        None
# 9395     None        None
# 9396     None        None
# 9397     None        None
# 9398     None        None
# 9399     None        None
# 9400     None        None
# 9401     None        None
# 9402     None        None
# 9403     None        None
# 9404     None        None
# 9405     None        None
# 9406     None        None
# 9407     None        None
#
# [9363 rows x 18 columns]

# %% [markdown]
# ## Часть 1. Предварительная обработка данных [10 баллов]
#
# 1. Удалите неоднозначные фамилии (т.е. одинаковые фамилии на разных языка), если такие есть;
# 2. Оцените
# * среднюю длину фамилии по всей коллекции
# * по каждому языку
# 3. Для последующей классификации (части 2 и 3) оздайте обучающее и тестовое множество так, чтобы в обучающем множестве классы были сбалансированы: то есть, в обучающее множество должно входить примерно одинаковое количество фамилий на разных ящыка.

# %% [markdown]
# ##  Часть 2. Базовый метод классификации [20 баллов]
#
#
#
# Используйте метод наивного Байеса, логистическую регрессию или любой другой метод для классификации фамилий: в качестве признаков используйте символьные $n$-граммы. Сравните результаты, получаемые при разных $n=2,3,4$ по $F$-мере и аккуратности. В каких случаях метод ошибается?
#
# Для генерации $n$-грамм используйте:

# %%
import nltk

# %%
from nltk.util import ngrams

# %%
chars = [char  for name in lines for char in name]
freq = nltk.FreqDist(chars)

print(list(freq.keys()))
# Out:
# ['A', 'd', 'a', 'm', 'c', 'z', 'k', 'y', 'n', 'r', 's', 'i', 'u', 't', 'e', 'b', 'g', 'B', 'o', 'ż', 'w', 'C', 'h', 'l', 'j', 'D', 'F', 'p', 'G', 'ó', 'J', 'K', 'ń', 'v', 'L', 'M', 'ł', 'N', 'P', 'R', 'S', 'f', 'Ś', 'ą', 'á', 'W', 'Z', 'Ż']

# %%
chars
# Out:
# ['A',
#  'd',
#  'a',
#  'm',
#  'c',
#  'z',
#  'a',
#  'k',
#  'A',
#  'd',
#  'a',
#  'm',
#  'c',
#  'z',
#  'y',
#  'k',
#  'A',
#  'n',
#  'd',
#  'r',
#  'y',
#  's',
#  'i',
#  'a',
#  'k',
#  'A',
#  'u',
#  't',
#  't',
#  'e',
#  'n',
#  'b',
#  'e',
#  'r',
#  'g',
#  'B',
#  'a',
#  'r',
#  't',
#  'o',
#  's',
#  'z',
#  'B',
#  'e',
#  'r',
#  'n',
#  'a',
#  'r',
#  'd',
#  'B',
#  'o',
#  'b',
#  'i',
#  'e',
#  'n',
#  's',
#  'k',
#  'i',
#  'B',
#  'o',
#  's',
#  'k',
#  'o',
#  'B',
#  'r',
#  'o',
#  'ż',
#  'B',
#  'r',
#  'z',
#  'e',
#  'z',
#  'i',
#  'c',
#  'k',
#  'i',
#  'B',
#  'u',
#  'd',
#  'n',
#  'y',
#  'B',
#  'u',
#  'k',
#  'o',
#  's',
#  'k',
#  'i',
#  'B',
#  'u',
#  'k',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'C',
#  'h',
#  'l',
#  'e',
#  'b',
#  'e',
#  'k',
#  'C',
#  'h',
#  'm',
#  'i',
#  'e',
#  'l',
#  'C',
#  'z',
#  'a',
#  'j',
#  'k',
#  'a',
#  'C',
#  'z',
#  'a',
#  'j',
#  'k',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'D',
#  'u',
#  'b',
#  'a',
#  'n',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'D',
#  'u',
#  'b',
#  'i',
#  'c',
#  'k',
#  'i',
#  'D',
#  'u',
#  'n',
#  'a',
#  'j',
#  's',
#  'k',
#  'i',
#  'D',
#  'z',
#  'i',
#  'e',
#  'd',
#  'z',
#  'i',
#  'c',
#  'F',
#  'a',
#  'b',
#  'i',
#  'a',
#  'n',
#  'F',
#  'i',
#  'l',
#  'i',
#  'p',
#  'e',
#  'k',
#  'F',
#  'i',
#  'l',
#  'i',
#  'p',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'G',
#  'a',
#  'j',
#  'o',
#  's',
#  'G',
#  'n',
#  'i',
#  'e',
#  'w',
#  'e',
#  'k',
#  'G',
#  'o',
#  'm',
#  'o',
#  'l',
#  'k',
#  'a',
#  'G',
#  'o',
#  'm',
#  'u',
#  'l',
#  'k',
#  'a',
#  'G',
#  'o',
#  'r',
#  'e',
#  'c',
#  'k',
#  'i',
#  'G',
#  'ó',
#  'r',
#  'k',
#  'a',
#  'G',
#  'ó',
#  'r',
#  's',
#  'k',
#  'i',
#  'G',
#  'r',
#  'z',
#  'e',
#  's',
#  'k',
#  'i',
#  'e',
#  'w',
#  'i',
#  'c',
#  'z',
#  'G',
#  'w',
#  'o',
#  'z',
#  'd',
#  'e',
#  'k',
#  'J',
#  'a',
#  'g',
#  'o',
#  'd',
#  'a',
#  'J',
#  'a',
#  'n',
#  'd',
#  'a',
#  'J',
#  'a',
#  'n',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'J',
#  'a',
#  's',
#  'k',
#  'o',
#  'l',
#  's',
#  'k',
#  'i',
#  'J',
#  'a',
#  's',
#  'k',
#  'u',
#  'l',
#  's',
#  'k',
#  'i',
#  'J',
#  'e',
#  'd',
#  'y',
#  'n',
#  'a',
#  'k',
#  'J',
#  'e',
#  'l',
#  'e',
#  'n',
#  'J',
#  'e',
#  'z',
#  'J',
#  'o',
#  'r',
#  'd',
#  'a',
#  'n',
#  'K',
#  'a',
#  'c',
#  'z',
#  'k',
#  'a',
#  'K',
#  'a',
#  'l',
#  'u',
#  'z',
#  'a',
#  'K',
#  'a',
#  'm',
#  'i',
#  'ń',
#  's',
#  'k',
#  'i',
#  'K',
#  'a',
#  's',
#  'p',
#  'r',
#  'z',
#  'a',
#  'k',
#  'K',
#  'a',
#  'v',
#  'a',
#  'K',
#  'e',
#  'd',
#  'z',
#  'i',
#  'e',
#  'r',
#  's',
#  'k',
#  'i',
#  'K',
#  'i',
#  'j',
#  'e',
#  'k',
#  'K',
#  'l',
#  'i',
#  'm',
#  'e',
#  'k',
#  'K',
#  'o',
#  's',
#  'm',
#  'a',
#  't',
#  'k',
#  'a',
#  'K',
#  'o',
#  'w',
#  'a',
#  'l',
#  'c',
#  'z',
#  'y',
#  'k',
#  'K',
#  'o',
#  'w',
#  'a',
#  'l',
#  's',
#  'k',
#  'i',
#  'K',
#  'o',
#  'z',
#  'i',
#  'o',
#  'l',
#  'K',
#  'o',
#  'z',
#  'l',
#  'o',
#  'w',
#  'K',
#  'o',
#  'z',
#  'l',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'K',
#  'r',
#  'a',
#  'k',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'K',
#  'r',
#  'ó',
#  'l',
#  'K',
#  'u',
#  'm',
#  'i',
#  'e',
#  'g',
#  'a',
#  'L',
#  'a',
#  'w',
#  'n',
#  'i',
#  'c',
#  'z',
#  'a',
#  'k',
#  'L',
#  'i',
#  's',
#  'M',
#  'a',
#  'j',
#  'e',
#  'w',
#  's',
#  'k',
#  'i',
#  'M',
#  'a',
#  'l',
#  'i',
#  'n',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'M',
#  'a',
#  'l',
#  'y',
#  'M',
#  'a',
#  'r',
#  'e',
#  'k',
#  'M',
#  'a',
#  'r',
#  's',
#  'z',
#  'a',
#  'ł',
#  'e',
#  'k',
#  'M',
#  'a',
#  's',
#  'l',
#  'a',
#  'n',
#  'k',
#  'a',
#  'M',
#  'e',
#  'n',
#  'c',
#  'h',
#  'e',
#  'r',
#  'M',
#  'i',
#  'a',
#  'z',
#  'g',
#  'a',
#  'M',
#  'i',
#  'c',
#  'h',
#  'e',
#  'l',
#  'M',
#  'i',
#  'k',
#  'o',
#  'l',
#  'a',
#  'j',
#  'c',
#  'z',
#  'a',
#  'k',
#  'M',
#  'o',
#  'z',
#  'd',
#  'z',
#  'i',
#  'e',
#  'r',
#  'z',
#  'N',
#  'i',
#  'e',
#  'm',
#  'c',
#  'z',
#  'y',
#  'k',
#  'N',
#  'i',
#  'e',
#  'm',
#  'e',
#  'c',
#  'N',
#  'o',
#  's',
#  'e',
#  'k',
#  'N',
#  'o',
#  'w',
#  'a',
#  'k',
#  'P',
#  'a',
#  'k',
#  'u',
#  'l',
#  's',
#  'k',
#  'i',
#  'P',
#  'a',
#  's',
#  't',
#  'e',
#  'r',
#  'n',
#  'a',
#  'c',
#  'k',
#  'P',
#  'a',
#  's',
#  't',
#  'e',
#  'r',
#  'n',
#  'a',
#  'k',
#  'P',
#  'a',
#  's',
#  'z',
#  'e',
#  'k',
#  'P',
#  'i',
#  'a',
#  't',
#  'e',
#  'k',
#  'P',
#  'i',
#  'o',
#  'n',
#  't',
#  'e',
#  'k',
#  'P',
#  'o',
#  'k',
#  'o',
#  'r',
#  'n',
#  'y',
#  'P',
#  'o',
#  'p',
#  'l',
#  'a',
#  'w',
#  's',
#  'k',
#  'i',
#  'R',
#  'ó',
#  'g',
#  'R',
#  'u',
#  'd',
#  'a',
#  's',
#  'k',
#  'i',
#  'R',
#  'u',
#  'd',
#  'a',
#  'w',
#  's',
#  'k',
#  'i',
#  'R',
#  'u',
#  's',
#  'n',
#  'a',
#  'k',
#  'R',
#  'u',
#  't',
#  'k',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'S',
#  'a',
#  'd',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'S',
#  'a',
#  'l',
#  'o',
#  'm',
#  'o',
#  'n',
#  'S',
#  'e',
#  'r',
#  'a',
#  'f',
#  'i',
#  'n',
#  'S',
#  'i',
#  'e',
#  'n',
#  'k',
#  'i',
#  'e',
#  'w',
#  'i',
#  'c',
#  'z',
#  'S',
#  'i',
#  'e',
#  'r',
#  'z',
#  'a',
#  'n',
#  't',
#  'S',
#  'i',
#  't',
#  'k',
#  'o',
#  'S',
#  'k',
#  'a',
#  'l',
#  'a',
#  'S',
#  'l',
#  'a',
#  's',
#  'k',
#  'i',
#  'Ś',
#  'l',
#  'ą',
#  'z',
#  'a',
#  'k',
#  'Ś',
#  'l',
#  'u',
#  's',
#  'a',
#  'r',
#  'c',
#  'z',
#  'y',
#  'k',
#  'Ś',
#  'l',
#  'u',
#  's',
#  'a',
#  'r',
#  's',
#  'k',
#  'i',
#  'S',
#  'm',
#  'o',
#  'l',
#  'á',
#  'k',
#  'S',
#  'n',
#  'i',
#  'e',
#  'g',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'S',
#  'o',
#  'b',
#  'o',
#  'l',
#  'S',
#  'o',
#  'k',
#  'a',
#  'l',
#  'S',
#  'o',
#  'k',
#  'o',
#  'l',
#  'o',
#  'f',
#  'S',
#  'o',
#  'k',
#  'o',
#  'l',
#  'o',
#  'f',
#  'f',
#  'S',
#  'o',
#  'k',
#  'o',
#  'l',
#  'o',
#  'f',
#  's',
#  'k',
#  'y',
#  'S',
#  'o',
#  'k',
#  'o',
#  'l',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'S',
#  'o',
#  'k',
#  'o',
#  'l',
#  's',
#  'k',
#  'y',
#  'S',
#  'ó',
#  'w',
#  'k',
#  'a',
#  'S',
#  't',
#  'a',
#  'n',
#  'e',
#  'k',
#  'S',
#  't',
#  'a',
#  'r',
#  'e',
#  'k',
#  'S',
#  't',
#  'a',
#  'w',
#  's',
#  'k',
#  'i',
#  'S',
#  't',
#  'o',
#  'l',
#  'a',
#  'r',
#  'z',
#  'S',
#  'z',
#  'c',
#  'z',
#  'e',
#  'p',
#  'a',
#  'n',
#  's',
#  'k',
#  'i',
#  'S',
#  'z',
#  'e',
#  'w',
#  'c',
#  'S',
#  'z',
#  'w',
#  'a',
#  'r',
#  'c',
#  'S',
#  'z',
#  'w',
#  'e',
#  'd',
#  'a',
#  'S',
#  'z',
#  'w',
#  'e',
#  'd',
#  'k',
#  'o',
#  'W',
#  'a',
#  'l',
#  'e',
#  'n',
#  't',
#  'o',
#  'w',
#  'i',
#  'c',
#  'z',
#  'W',
#  'a',
#  'r',
#  's',
#  'z',
#  'a',
#  'w',
#  's',
#  'k',
#  'i',
#  'W',
#  'a',
#  'w',
#  'r',
#  'z',
#  'a',
#  's',
#  'z',
#  'e',
#  'k',
#  'W',
#  'i',
#  'a',
#  't',
#  'e',
#  'r',
#  'W',
#  'i',
#  'n',
#  'o',
#  'g',
#  'r',
#  'a',
#  'd',
#  'W',
#  'i',
#  'n',
#  'o',
#  'g',
#  'r',
#  'o',
#  'd',
#  'z',
#  'k',
#  'i',
#  'W',
#  'o',
#  'j',
#  'd',
#  'a',
#  'W',
#  'o',
#  'j',
#  'e',
#  'w',
#  'ó',
#  'd',
#  'k',
#  'a',
#  'W',
#  'o',
#  'j',
#  'e',
#  'w',
#  'ó',
#  'd',
#  'z',
#  'k',
#  'i',
#  'W',
#  'r',
#  'o',
#  'n',
#  's',
#  'k',
#  'i',
#  'W',
#  'y',
#  'r',
#  'i',
#  'c',
#  'k',
#  'W',
#  'y',
#  'r',
#  'z',
#  'y',
#  'k',
#  'Z',
#  'a',
#  'b',
#  'e',
#  'k',
#  'Z',
#  'a',
#  'w',
#  'i',
#  's',
#  'z',
#  'a',
#  'Z',
#  'd',
#  'u',
#  'n',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'Z',
#  'd',
#  'u',
#  'n',
#  'o',
#  'w',
#  's',
#  'k',
#  'i',
#  'Z',
#  'i',
#  'e',
#  'l',
#  'i',
#  'n',
#  's',
#  'k',
#  'i',
#  'Z',
#  'i',
#  'e',
#  'm',
#  'n',
#  'i',
#  'a',
#  'k',
#  'Z',
#  'i',
#  ...]

# %%
cfreq = nltk.ConditionalFreqDist(nltk.bigrams(chars))
cfreq['a']
# Out:
# FreqDist({'C': 1,
#           'G': 3,
#           'J': 2,
#           'K': 4,
#           'L': 1,
#           'M': 2,
#           'S': 3,
#           'W': 2,
#           'Z': 1,
#           'b': 2,
#           'c': 2,
#           'd': 2,
#           'f': 1,
#           'g': 1,
#           'j': 6,
#           'k': 13,
#           'l': 9,
#           'm': 3,
#           'n': 9,
#           'r': 10,
#           's': 10,
#           't': 3,
#           'v': 1,
#           'w': 8,
#           'z': 1,
#           'ł': 1})

# %%
import nltk

from sklearn.utils import shuffle

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import LSTM, TimeDistributed, Bidirectional
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, Flatten, Dropout
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
chars = [char  for name in lines for char in name]
freq = nltk.FreqDist(chars)

print(list(freq.keys()))
# Out:
# ['A', 'd', 'a', 'm', 'c', 'z', 'k', 'y', 'n', 'r', 's', 'i', 'u', 't', 'e', 'b', 'g', 'B', 'o', 'ż', 'w', 'C', 'h', 'l', 'j', 'D', 'F', 'p', 'G', 'ó', 'J', 'K', 'ń', 'v', 'L', 'M', 'ł', 'N', 'P', 'R', 'S', 'f', 'Ś', 'ą', 'á', 'W', 'Z', 'Ż']

# %% [markdown]
# ##  Часть 3. Нейронная сеть [35 баллов]
#
#
# Используйте  реккурентную нейронную сеть с  LSTM для решения задачи. В ней может быть несколько слоев с LSTM, несколько слоев c Bidirectional(LSTM).  У нейронной сети один выход, определяющий класс фамилии.
#
# Представление имени для классификации в этом случае:
# 1 вариант: бинарная матрица размера (количество букв в корпусе $\times$ максимальная длина имени). Обозначим его через $x$. Если первая буква имени a, то $x[1][1] = 1$, если вторая – b, то  $x[2][1] = 1$. То есть, используем one hot encoding для векторизации букв.
# 2 вариант: Embedding'и символов.
#
# Выберите тот вариант, который вам проще или интереснее реализовать :)
#
# Не забудьте про регуляризацию нейронной сети дропаутами.
#
# Сравните результаты классификации разными методами по accuracy, micro- и macro- F-measure, precision, recall. Какой метод лучше и почему?
#
# Сравните результаты, получаемые при разных значениях дропаута, разных числах узлов на слоях нейронной сети по $F$-мере и аккуратности. В каких случаях нейронная сеть ошибается?

# %% [markdown]
# Если совсем не получается запрограммировать нейронную сеть самостоятельно, обратитесь к туториалу тут: https://github.com/divamgupta/lstm-gender-predictor

# %% [markdown]
# ##  Часть 4. Генерация фамилии [35 баллов]
#
# Используйте архитектуру нейронной сети из Части 3 для генерации имени. В этот момент можно забыть про разбиение коллекции на обучающее и тестовое множество.
#
# Рассмотрите два сценария генерация имени:
# * обучение нейронной сети по всей коллекции
# * обучение нейронной сети с обуславливанием на язык
#
# Для обуславливания на язык нужно изменить векторное представление фамилии. До этого момента мы разбивали фамилию на отдельные символы и находили векторное представление каждого символа. Теперь добавим в начало фамилии метку языка и будем ее считать первым символов фамилии. Так нейронная сеть научиться понимать, на каком языке написана фамилия.
#
# Пример: ```[rus bos i v a n o v eos pad pad pad]```
#
# Когда будем генерировать новую фамилию, будем начинать процесс генерации не с символа начала последовательности ```bos```, а с символа языка и символа начала последовательности ```rus bos```.
#
# Привидите несколько примеров удачно сгенерированных фамилий.
